# %% [markdown]
# ## Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ## Importing Data from JSON files

# %%
import pandas as pd
import json

# %%
with open("blockbusters.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 136},
#  {'title': 'Avengers: Infinity War',
#   'id': 299536,
#   'revenue': 2046239637,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 149},
#  {'title': 'Titanic',
#   'id': 597,
#   'revenue': 1845034188,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': None,
#   'runtime': 194},
#  {'title': 'Jurassic World',
#   'id': 135397,
#   'revenue': 1671713208,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 124},
#  {'title': 'The Lion King',
#   'id': 420818,
#   'revenue': 1656943394,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': None,
#   'runtime': 118},
#  {'title': 'The Avengers',
#   'id': 24428,
#   'revenue': 1519557910,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 143},
#  {'title': 'Furious 7',
#   'id': 168259,
#   'revenue': 1506249360,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'runtime': 137},
#  {'title': 'Avengers: Age of Ultron',
#   'id': 99861,
#   'revenue': 1405403694,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 141},
#  {'title': 'Black Panther',
#   'id': 284054,
#   'revenue': 1346739107,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   'runtime': 134},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'id': 12445,
#   'revenue': 1341511219,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   'runtime': 130},
#  {'title': 'Star Wars: The Last Jedi',
#   'id': 181808,
#   'revenue': 1332539889,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 152},
#  {'title': 'Frozen II',
#   'id': 330457,
#   'revenue': 1330764959,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 104},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'id': 351286,
#   'revenue': 1303459585,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 129},
#  {'title': 'Frozen',
#   'id': 109445,
#   'revenue': 1274219009,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 102},
#  {'title': 'Beauty and the Beast',
#   'id': 321612,
#   'revenue': 1263521126,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'belongs_to_collection': None,
#   'runtime': 129},
#  {'title': 'Incredibles 2',
#   'id': 260513,
#   'revenue': 1241891456,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'},
#   'runtime': 118}]

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 18

# %%
data[0]
# Out:
# {'title': 'Avengers: Endgame',
#  'id': 299534,
#  'revenue': 2797800564,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'}],
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'runtime': 181}

# %%
df = pd.DataFrame(data)
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df = pd.read_json("blockbusters.json", orient = "record")
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 992.0+ bytes

# %%
df.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  runtime  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      136
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      134
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      152
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      104
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection_id           belongs_to_collection_name  \
# 0                    86311.0              The Avengers Collection
# 1                    87096.0                    Avatar Collection
# 2                       10.0                 Star Wars Collection
# 3                    86311.0              The Avengers Collection
# 4                        NaN                                  NaN
# 5                      328.0             Jurassic Park Collection
# 6                        NaN                                  NaN
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                    86311.0              The Avengers Collection
# 10                  529892.0             Black Panther Collection
# 11                    1241.0              Harry Potter Collection
# 12                      10.0                 Star Wars Collection
# 13                  386382.0                    Frozen Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 1   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 2   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 3   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 4                                NaN                                 NaN
# 5   /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 6                                NaN                                 NaN
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /uv63yAGg1zETAs1XQsOQpava87l.jpg    /z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg
# 9   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 10  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 11  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg
# 12  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 13  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 14  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 15  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 16                               NaN                                 NaN
# 17  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"],
                  record_prefix = "genre_")
# Out:
#     genre_id       genre_name                                         title  \
# 0         12        Adventure                             Avengers: Endgame
# 1        878  Science Fiction                             Avengers: Endgame
# 2         28           Action                             Avengers: Endgame
# 3         28           Action                                        Avatar
# 4         12        Adventure                                        Avatar
# 5         14          Fantasy                                        Avatar
# 6        878  Science Fiction                                        Avatar
# 7         28           Action                  Star Wars: The Force Awakens
# 8         12        Adventure                  Star Wars: The Force Awakens
# 9        878  Science Fiction                  Star Wars: The Force Awakens
# 10        14          Fantasy                  Star Wars: The Force Awakens
# 11        12        Adventure                        Avengers: Infinity War
# 12        28           Action                        Avengers: Infinity War
# 13       878  Science Fiction                        Avengers: Infinity War
# 14        18            Drama                                       Titanic
# 15     10749          Romance                                       Titanic
# 16        53         Thriller                                       Titanic
# 17        28           Action                                Jurassic World
# 18        12        Adventure                                Jurassic World
# 19       878  Science Fiction                                Jurassic World
# 20        53         Thriller                                Jurassic World
# 21        12        Adventure                                 The Lion King
# 22     10751           Family                                 The Lion King
# 23       878  Science Fiction                                  The Avengers
# 24        28           Action                                  The Avengers
# 25        12        Adventure                                  The Avengers
# 26        28           Action                                     Furious 7
# 27        53         Thriller                                     Furious 7
# 28        28           Action                       Avengers: Age of Ultron
# 29        12        Adventure                       Avengers: Age of Ultron
# 30       878  Science Fiction                       Avengers: Age of Ultron
# 31        28           Action                                 Black Panther
# 32        12        Adventure                                 Black Panther
# 33        14          Fantasy                                 Black Panther
# 34       878  Science Fiction                                 Black Panther
# 35        14          Fantasy  Harry Potter and the Deathly Hallows: Part 2
# 36        12        Adventure  Harry Potter and the Deathly Hallows: Part 2
# 37        14          Fantasy                      Star Wars: The Last Jedi
# 38        12        Adventure                      Star Wars: The Last Jedi
# 39       878  Science Fiction                      Star Wars: The Last Jedi
# 40        28           Action                      Star Wars: The Last Jedi
# 41        16        Animation                                     Frozen II
# 42     10751           Family                                     Frozen II
# 43        12        Adventure                                     Frozen II
# 44        28           Action                Jurassic World: Fallen Kingdom
# 45        12        Adventure                Jurassic World: Fallen Kingdom
# 46       878  Science Fiction                Jurassic World: Fallen Kingdom
# 47        16        Animation                                        Frozen
# 48        12        Adventure                                        Frozen
# 49     10751           Family                                        Frozen
# 50     10751           Family                          Beauty and the Beast
# 51        14          Fantasy                          Beauty and the Beast
# 52     10749          Romance                          Beauty and the Beast
# 53        28           Action                                 Incredibles 2
# 54        12        Adventure                                 Incredibles 2
# 55        16        Animation                                 Incredibles 2
# 56     10751           Family                                 Incredibles 2
#
#         id
# 0   299534
# 1   299534
# 2   299534
# 3    19995
# 4    19995
# 5    19995
# 6    19995
# 7   140607
# 8   140607
# 9   140607
# 10  140607
# 11  299536
# 12  299536
# 13  299536
# 14     597
# 15     597
# 16     597
# 17  135397
# 18  135397
# 19  135397
# 20  135397
# 21  420818
# 22  420818
# 23   24428
# 24   24428
# 25   24428
# 26  168259
# 27  168259
# 28   99861
# 29   99861
# 30   99861
# 31  284054
# 32  284054
# 33  284054
# 34  284054
# 35   12445
# 36   12445
# 37  181808
# 38  181808
# 39  181808
# 40  181808
# 41  330457
# 42  330457
# 43  330457
# 44  351286
# 45  351286
# 46  351286
# 47  109445
# 48  109445
# 49  109445
# 50  321612
# 51  321612
# 52  321612
# 53  260513
# 54  260513
# 55  260513
# 56  260513

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %%
api_key  = "api_key=213e65689cb3b77f0c46f74e74jklc896"

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
movie_id = 140607

# %%
movie_api = "https://api.themoviedb.org/3/movie/{}?"
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/{}?'

# %%
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=608e6f7bccb3b77f0c46f74e73adc525'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 63.835,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 11461,
#    'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#    'name': 'Bad Robot',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2015-12-15',
#  'revenue': 2068223624,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Every generation has a story.',
#  'title': 'Star Wars: The Force Awakens',
#  'video': False,
#  'vote_average': 7.315,
#  'vote_count': 17325}

# %%
type(data)
# Out:
# dict

# %%
#pd.DataFrame(data)

# %%
pd.Series(data)
# Out:
# adult                                                                False
# backdrop_path                             /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# belongs_to_collection    {'id': 10, 'name': 'Star Wars Collection', 'po...
# budget                                                           245000000
# genres                   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# homepage                 http://www.starwars.com/films/star-wars-episod...
# id                                                                  140607
# imdb_id                                                          tt2488496
# original_language                                                       en
# original_title                                Star Wars: The Force Awakens
# overview                 Thirty years after defeating the Galactic Empi...
# popularity                                                          63.835
# poster_path                               /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# production_companies     [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    2015-12-15
# revenue                                                         2068223624
# runtime                                                                136
# spoken_languages         [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                            Released
# tagline                                      Every generation has a story.
# title                                         Star Wars: The Force Awakens
# video                                                                False
# vote_average                                                         7.315
# vote_count                                                           17325
# dtype: object

# %%
df = pd.Series(data).to_frame().T
df
# Out:
#    adult                     backdrop_path  \
# 0  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  Thirty years after defeating the Galactic Empi...     63.835
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#   runtime                                   spoken_languages    status  \
# 0     136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#   vote_average vote_count
# 0        7.315      17325

# %%
pd.json_normalize(data, sep = "_")
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  \
# 0  Thirty years after defeating the Galactic Empi...      63.835
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#    runtime                                   spoken_languages    status  \
# 0      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#    vote_average  vote_count  belongs_to_collection_id  \
# 0         7.315       17325                        10
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Star Wars Collection  /gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg
#
#   belongs_to_collection_backdrop_path
# 0    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg

# %%
pd.json_normalize(data = data, record_path = "genres", meta = "title")
# Out:
#     id             name                         title
# 0   12        Adventure  Star Wars: The Force Awakens
# 1   28           Action  Star Wars: The Force Awakens
# 2  878  Science Fiction  Star Wars: The Force Awakens
# 3   14          Fantasy  Star Wars: The Force Awakens

# %%
pd.json_normalize(data = data, record_path = "production_companies", meta = "title")
# Out:
#       id                         logo_path            name origin_country  \
# 0      1  /o86DbpburjxrqAzEDhXZcyE8pDb.png  Lucasfilm Ltd.             US
# 1  11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png       Bad Robot             US
#
#                           title
# 0  Star Wars: The Force Awakens
# 1  Star Wars: The Force Awakens

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29"

# %%
url = discover_api+api_key+query

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/yy85YPsJEVxCy97A89cAwdsCUXa.jpg',
#    'genre_ids': [18, 10749],
#    'id': 677115,
#    'original_language': 'ko',
#    'original_title': '비뇨기과 여의사들 2',
#    'overview': 'Jin Hee is a female urologist who runs a urology department with few patients. One day, a new nurse, Yeon-hee, comes in and works. However, she throws her her whole body in the treatment of patients with an unusual professional spirit. This fact is quickly rumored and patients flock in. Skilled female doctor Jin Hee also starts hot treatment to save the hospital...',
#    'popularity': 150.882,
#    'poster_path': '/uksxhYz0Xc7c5AIjoU205XXEVk8.jpg',
#    'release_date': '2020-02-20',
#    'title': 'Female Urologists 2',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 5},
#   {'adult': False,
#    'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg',
#    'genre_ids': [28, 878, 35, 10751],
#    'id': 454626,
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog',
#    'overview': 'Powered with incredible speed, Sonic The Hedgehog embraces his new home on Earth. That is, until Sonic sparks the attention of super-uncool evil genius Dr. Robotnik. Now it’s super-villain vs. super-sonic in an all-out race across the globe to stop Robotnik from using Sonic’s unique power for world domination.',
#    'popularity': 125.874,
#    'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Sonic the Hedgehog',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 8281},
#   {'adult': False,
#    'backdrop_path': '/ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg',
#    'genre_ids': [16, 12, 28, 14],
#    'id': 631132,
#    'original_language': 'ja',
#    'original_title': "ゴブリンスレイヤー -GOBLIN'S CROWN-",
#    'overview': 'Goblin Slayer and his party head up to the snowy mountains in the north after receiving that request from the Sword Maiden to find any information on the Noble Fencer that disappeared after leaving to slay some goblins. A small village gets attacked, they encounter a mysterious chapel, and something about how these goblins are acting bothers the Goblin slayer.  In order to save the captured Noble Fencer, the Goblin Slayer and his party head to an ancient fortress covered in snow to face off with a powerful foe and a horde of goblins!',
#    'popularity': 101.789,
#    'poster_path': '/oyDaF4za9C9GxfYSyZUmj2aZGJT.jpg',
#    'release_date': '2020-02-01',
#    'title': "Goblin Slayer: Goblin's Crown",
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 171},
#   {'adult': False,
#    'backdrop_path': '/tmS9oXeMVs6njcxndDKsjJSF02H.jpg',
#    'genre_ids': [18],
#    'id': 552532,
#    'original_language': 'en',
#    'original_title': 'Charm City Kings',
#    'overview': 'Mouse desperately wants to join The Midnight Clique, the infamous Baltimore dirt bike riders who rule the summertime streets. When Midnight’s leader, Blax, takes 14-year-old Mouse under his wing, Mouse soon finds himself torn between the straight-and-narrow and a road filled with fast money and violence.',
#    'popularity': 78.107,
#    'poster_path': '/8oiMFMarbRpcusASIX4cjVXoZKI.jpg',
#    'release_date': '2020-01-27',
#    'title': 'Charm City Kings',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 321},
#   {'adult': False,
#    'backdrop_path': '/uozb2VeD87YmhoUP1RrGWfzuCrr.jpg',
#    'genre_ids': [28, 80],
#    'id': 495764,
#    'original_language': 'en',
#    'original_title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'overview': 'Harley Quinn joins forces with a singer, an assassin and a police detective to help a young girl who had a hit placed on her after she stole a rare diamond from a crime lord.',
#    'popularity': 90.12,
#    'poster_path': '/h4VB6m0RwcicVEZvzftYZyKXs6K.jpg',
#    'release_date': '2020-02-05',
#    'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 8968},
#   {'adult': False,
#    'backdrop_path': '/pQdZmXq0vvKP1RYUrDHQkzMlS4x.jpg',
#    'genre_ids': [16, 28, 12, 14],
#    'id': 571265,
#    'original_language': 'ja',
#    'original_title': 'デジモンアドベンチャー LAST EVOLUTION 絆',
#    'overview': 'Tai is now a university student, living alone, working hard at school, and working every day, but with his future still undecided. Meanwhile, Matt and others continue to work on Digimon incidents and activities that help people with their partner Digimon. When an unprecedented phenomenon occurs, the DigiDestined discover that when they grow up, their relationship with their partner Digimon will come closer to an end.  As a countdown timer activates on the Digivice, they realize that the more they fight with their partner Digimon, the faster their bond breaks. Will they fight for others and lose their partner? The time to choose and decide is approaching fast. There is a short time before “chosen children” will become adults. This is the last adventure of Tai and Agumon.',
#    'popularity': 87.424,
#    'poster_path': '/z3l5iwWQLxcInVnNkC8k8hxqZ60.jpg',
#    'release_date': '2020-02-21',
#    'title': 'Digimon Adventure: Last Evolution Kizuna',
#    'video': False,
#    'vote_average': 8.1,
#    'vote_count': 174},
#   {'adult': False,
#    'backdrop_path': '/3N316jUSdhvPyYTW29G4v9ebbcS.jpg',
#    'genre_ids': [53, 28, 80],
#    'id': 38700,
#    'original_language': 'en',
#    'original_title': 'Bad Boys for Life',
#    'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.',
#    'popularity': 78.855,
#    'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg',
#    'release_date': '2020-01-15',
#    'title': 'Bad Boys for Life',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 7122},
#   {'adult': False,
#    'backdrop_path': '/isBjNHBblzxrzHrAtRbjgkYzAut.jpg',
#    'genre_ids': [10749, 18],
#    'id': 664413,
#    'original_language': 'pl',
#    'original_title': '365 dni',
#    'overview': 'A woman falls victim to a dominant mafia boss, who imprisons her and gives her one year to fall in love with him.',
#    'popularity': 70.073,
#    'poster_path': '/6KwrHucIE3CvNT7kTm2MAlZ4fYF.jpg',
#    'release_date': '2020-02-07',
#    'title': '365 Days',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 7500},
#   {'adult': False,
#    'backdrop_path': '/rc8WAwoTTZ5HDUDBiKhIohbl57A.jpg',
#    'genre_ids': [27],
#    'id': 575088,
#    'original_language': 'ru',
#    'original_title': 'Яга. Кошмар тёмного леса',
#    'overview': 'The young family who moved to a new apartment on the outskirts of the city. The nanny hired by them for the newborn daughter quickly gained confidence. However, the older boy, Egor, talks about the frightening behavior of a woman, but his parents do not believe him. The surveillance cameras installed by the father for comfort only confirm everything is in order. Then one day, Egor, returning home, finds no trace of either the nanny or the little sister, and the parents are in a strange trance and do not even remember that they had a daughter. Then Egor, together with his friends, goes in search, during which it turns out that the nanny is an ancient Slavic demon, popularly known as Baba Yaga.',
#    'popularity': 58.341,
#    'poster_path': '/8m5HTXzwewlfXhtZtLlLts53YTW.jpg',
#    'release_date': '2020-02-27',
#    'title': 'Baba Yaga: Terror of the Dark Forest',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 186},
#   {'adult': False,
#    'backdrop_path': '/cpTjuXuNTEDJc7qJEiUbUGcn85F.jpg',
#    'genre_ids': [27, 35],
#    'id': 664168,
#    'original_language': 'en',
#    'original_title': 'Fat Ass Zombies',
#    'overview': 'In a sleepy town, one man, a wannabe horror film director is about to have his life and the world he knows change forever. Finally, he gets the big break he has been waiting a lifetime for, but its not Hollywood knocking on his door.',
#    'popularity': 54.687,
#    'poster_path': '/btrers8SNujMJhxjLvjh7AJpN3T.jpg',
#    'release_date': '2020-02-18',
#    'title': 'Fat Ass Zombies',
#    'video': False,
#    'vote_average': 4.9,
#    'vote_count': 47},
#   {'adult': False,
#    'backdrop_path': '/AgkGh4epJyhvs9JqSEUVABz1gJh.jpg',
#    'genre_ids': [10751, 14, 12],
#    'id': 448119,
#    'original_language': 'en',
#    'original_title': 'Dolittle',
#    'overview': 'After losing his wife seven years earlier, the eccentric Dr. John Dolittle, famed doctor and veterinarian of Queen Victoria’s England, hermits himself away behind the high walls of Dolittle Manor with only his menagerie of exotic animals for company. But when the young queen falls gravely ill, a reluctant Dolittle is forced to set sail on an epic adventure to a mythical island in search of a cure, regaining his wit and courage as he crosses old adversaries and discovers wondrous creatures.',
#    'popularity': 61.049,
#    'poster_path': '/uoplwswBDy7gsOyrbGuKyPFoPCs.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Dolittle',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 3053},
#   {'adult': False,
#    'backdrop_path': '/v7eMYrYpcTJORioMKMgjnzyewWH.jpg',
#    'genre_ids': [10749],
#    'id': 679057,
#    'original_language': 'ko',
#    'original_title': '가슴 큰 태희',
#    'overview': 'Cha-wook and Min-joo are about to get married. Cha-wook proposes a couple trip to Yong-woo’s wife who is his junior at work. Ji-yeon doesn’t like uncomfortable trips but Yong-woo’s boss forced her. The trip has been decided and Cha-wook plans to stay with Ji-yeon, who he’s been eyeing. Min-joo is forced to join. On the day of the trip, Min-joo finally tells everything to Ji-yeon and Ji-yeon decides to use Cha-wook.',
#    'popularity': 39.076,
#    'poster_path': '/aKoGgpKn6N04kWQp03LSAweN3dn.jpg',
#    'release_date': '2020-02-27',
#    'title': 'Bosomy Tae-hee',
#    'video': False,
#    'vote_average': 8.3,
#    'vote_count': 3},
#   {'adult': False,
#    'backdrop_path': '/bpHseZ8Vwh3nk7cowKxQ68Dm2Xq.jpg',
#    'genre_ids': [53, 18, 28],
#    'id': 616803,
#    'original_language': 'sv',
#    'original_title': 'Breaking Surface',
#    'overview': 'Two Swedish/Norwegian half sisters go on a winter diving trip in Northern Norway, when they get trapped after a rockslide.',
#    'popularity': 37.044,
#    'poster_path': '/zlOvKg5WkXcwcmqy2KaiXoXLAky.jpg',
#    'release_date': '2020-02-14',
#    'title': 'Breaking Surface',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 309},
#   {'adult': False,
#    'backdrop_path': '/kLsrE6q4ld144ECBkydZ4dV8t9T.jpg',
#    'genre_ids': [27],
#    'id': 648990,
#    'original_language': 'es',
#    'original_title': 'La casa',
#    'overview': 'Responding to an urgent call for help, a police officer becomes trapped by the evil spirits of a cursed house.',
#    'popularity': 43.223,
#    'poster_path': '/fvTGWaQejnHQBZbEOrdbb38NBTC.jpg',
#    'release_date': '2020-01-30',
#    'title': 'La Casa',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 77},
#   {'adult': False,
#    'backdrop_path': '/tcrNJfyNEIqaBR8Ogkgnq5xQJnf.jpg',
#    'genre_ids': [10749, 18],
#    'id': 342470,
#    'original_language': 'en',
#    'original_title': 'All the Bright Places',
#    'overview': 'Two teens facing personal struggles form a powerful bond as they embark on a cathartic journey chronicling the wonders of Indiana.',
#    'popularity': 44.021,
#    'poster_path': '/4SafxuMKQiw4reBiWKVZJpJn80I.jpg',
#    'release_date': '2020-02-28',
#    'title': 'All the Bright Places',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 2488},
#   {'adult': False,
#    'backdrop_path': '/yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg',
#    'genre_ids': [12, 10751, 18],
#    'id': 481848,
#    'original_language': 'en',
#    'original_title': 'The Call of the Wild',
#    'overview': 'Buck is a big-hearted dog whose blissful domestic life is turned upside down when he is suddenly uprooted from his California home and transplanted to the exotic wilds of the Yukon during the Gold Rush of the 1890s. As the newest rookie on a mail delivery dog sled team—and later its leader—Buck experiences the adventure of a lifetime, ultimately finding his true place in the world and becoming his own master.',
#    'popularity': 52.411,
#    'poster_path': '/33VdppGbeNxICrFUtW2WpGHvfYc.jpg',
#    'release_date': '2020-02-19',
#    'title': 'The Call of the Wild',
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 2963},
#   {'adult': False,
#    'backdrop_path': '/aiQICxiWNcOsJruYxdPuhb6WtWu.jpg',
#    'genre_ids': [9648, 18, 27, 12, 16],
#    'id': 658558,
#    'original_language': 'ja',
#    'original_title': '劇場版 巨蟲列島',
#    'overview': "After an airplane crash during a school trip, Oribe Mutsumi and her classmates were stranded on a seemingly deserted island. Mutsumi found the other survivors, and used her wilderness knowledge to help them. She expects that they will be rescued in about three days, which doesn't seem so long to endure. However, she didn't account for the fact that the island is populated with gigantic killer insects. Her knowledge of butterflies, wasps, and more may be the only thing that will help any of her classmates survive to be rescued!",
#    'popularity': 58.747,
#    'poster_path': '/uJFki1BLHvEi4gaPCJvy9SZQZpx.jpg',
#    'release_date': '2020-01-10',
#    'title': 'The Island of Giant Insects',
#    'video': False,
#    'vote_average': 4.4,
#    'vote_count': 15},
#   {'adult': False,
#    'backdrop_path': '/xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg',
#    'genre_ids': [10751, 16, 12, 35, 14],
#    'id': 508439,
#    'original_language': 'en',
#    'original_title': 'Onward',
#    'overview': 'In a suburban fantasy world, two teenage elf brothers embark on an extraordinary quest to discover if there is still a little magic left out there.',
#    'popularity': 44.276,
#    'poster_path': '/f4aul3FyD3jv3v4bul1IrkWZvzq.jpg',
#    'release_date': '2020-02-29',
#    'title': 'Onward',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 5166},
#   {'adult': False,
#    'backdrop_path': '/sCtJkYwBrJm8mygRrDGyluf1gSV.jpg',
#    'genre_ids': [27, 878, 53],
#    'id': 736509,
#    'original_language': 'en',
#    'original_title': 'Intersect',
#    'overview': 'A group of young Miskatonic University scientists invent a time machine, only to learn that they are being manipulated by mysterious, unseen forces from another dimension.',
#    'popularity': 36.728,
#    'poster_path': '/e6hgmD0P133bW5EH1kfhscwXN2a.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Intersect',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 48},
#   {'adult': False,
#    'backdrop_path': '/1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg',
#    'genre_ids': [35, 53, 80],
#    'id': 609242,
#    'original_language': 'es',
#    'original_title': 'El robo del siglo',
#    'overview': 'In 2006, a group of thieves performed what is considered one of the most famous and smart bank heists in the history of Argentina. How they robbed the Rio bank is as surprising as what happened afterwards. This is their story.',
#    'popularity': 37.585,
#    'poster_path': '/1zL4VCVin4S8kOXhszMDqfwWPCM.jpg',
#    'release_date': '2020-01-16',
#    'title': 'The Heist of the Century',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 643}],
#  'total_pages': 253,
#  'total_results': 5058}

# %%
pd.DataFrame(data)
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/yy85YPsJEV...          253
# 1      1  {'adult': False, 'backdrop_path': '/stmYfCUGd8...          253
# 2      1  {'adult': False, 'backdrop_path': '/ySHlkHDbXz...          253
# 3      1  {'adult': False, 'backdrop_path': '/tmS9oXeMVs...          253
# 4      1  {'adult': False, 'backdrop_path': '/uozb2VeD87...          253
# 5      1  {'adult': False, 'backdrop_path': '/pQdZmXq0vv...          253
# 6      1  {'adult': False, 'backdrop_path': '/3N316jUSdh...          253
# 7      1  {'adult': False, 'backdrop_path': '/isBjNHBblz...          253
# 8      1  {'adult': False, 'backdrop_path': '/rc8WAwoTTZ...          253
# 9      1  {'adult': False, 'backdrop_path': '/cpTjuXuNTE...          253
# 10     1  {'adult': False, 'backdrop_path': '/AgkGh4epJy...          253
# 11     1  {'adult': False, 'backdrop_path': '/v7eMYrYpcT...          253
# 12     1  {'adult': False, 'backdrop_path': '/bpHseZ8Vwh...          253
# 13     1  {'adult': False, 'backdrop_path': '/kLsrE6q4ld...          253
# 14     1  {'adult': False, 'backdrop_path': '/tcrNJfyNEI...          253
# 15     1  {'adult': False, 'backdrop_path': '/yFRpUmsreY...          253
# 16     1  {'adult': False, 'backdrop_path': '/aiQICxiWNc...          253
# 17     1  {'adult': False, 'backdrop_path': '/xFxk4vnirO...          253
# 18     1  {'adult': False, 'backdrop_path': '/sCtJkYwBrJ...          253
# 19     1  {'adult': False, 'backdrop_path': '/1umKVgbjFG...          253
#
#     total_results
# 0            5058
# 1            5058
# 2            5058
# 3            5058
# 4            5058
# 5            5058
# 6            5058
# 7            5058
# 8            5058
# 9            5058
# 10           5058
# 11           5058
# 12           5058
# 13           5058
# 14           5058
# 15           5058
# 16           5058
# 17           5058
# 18           5058
# 19           5058

# %%
pd.DataFrame(data["results"])
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /yy85YPsJEVxCy97A89cAwdsCUXa.jpg              [18, 10749]  677115
# 1   False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg     [28, 878, 35, 10751]  454626
# 2   False  /ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg         [16, 12, 28, 14]  631132
# 3   False  /tmS9oXeMVs6njcxndDKsjJSF02H.jpg                     [18]  552532
# 4   False  /uozb2VeD87YmhoUP1RrGWfzuCrr.jpg                 [28, 80]  495764
# 5   False  /pQdZmXq0vvKP1RYUrDHQkzMlS4x.jpg         [16, 28, 12, 14]  571265
# 6   False  /3N316jUSdhvPyYTW29G4v9ebbcS.jpg             [53, 28, 80]   38700
# 7   False  /isBjNHBblzxrzHrAtRbjgkYzAut.jpg              [10749, 18]  664413
# 8   False  /rc8WAwoTTZ5HDUDBiKhIohbl57A.jpg                     [27]  575088
# 9   False  /cpTjuXuNTEDJc7qJEiUbUGcn85F.jpg                 [27, 35]  664168
# 10  False  /AgkGh4epJyhvs9JqSEUVABz1gJh.jpg          [10751, 14, 12]  448119
# 11  False  /v7eMYrYpcTJORioMKMgjnzyewWH.jpg                  [10749]  679057
# 12  False  /bpHseZ8Vwh3nk7cowKxQ68Dm2Xq.jpg             [53, 18, 28]  616803
# 13  False  /kLsrE6q4ld144ECBkydZ4dV8t9T.jpg                     [27]  648990
# 14  False  /tcrNJfyNEIqaBR8Ogkgnq5xQJnf.jpg              [10749, 18]  342470
# 15  False  /yFRpUmsreYO5Bc0HVBTsJsHIIox.jpg          [12, 10751, 18]  481848
# 16  False  /aiQICxiWNcOsJruYxdPuhb6WtWu.jpg   [9648, 18, 27, 12, 16]  658558
# 17  False  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg  [10751, 16, 12, 35, 14]  508439
# 18  False  /sCtJkYwBrJm8mygRrDGyluf1gSV.jpg            [27, 878, 53]  736509
# 19  False  /1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg             [35, 53, 80]  609242
#
#    original_language                                     original_title  \
# 0                 ko                                        비뇨기과 여의사들 2
# 1                 en                                 Sonic the Hedgehog
# 2                 ja                         ゴブリンスレイヤー -GOBLIN'S CROWN-
# 3                 en                                   Charm City Kings
# 4                 en  Birds of Prey (and the Fantabulous Emancipatio...
# 5                 ja                       デジモンアドベンチャー LAST EVOLUTION 絆
# 6                 en                                  Bad Boys for Life
# 7                 pl                                            365 dni
# 8                 ru                           Яга. Кошмар тёмного леса
# 9                 en                                    Fat Ass Zombies
# 10                en                                           Dolittle
# 11                ko                                            가슴 큰 태희
# 12                sv                                   Breaking Surface
# 13                es                                            La casa
# 14                en                              All the Bright Places
# 15                en                               The Call of the Wild
# 16                ja                                           劇場版 巨蟲列島
# 17                en                                             Onward
# 18                en                                          Intersect
# 19                es                                  El robo del siglo
#
#                                              overview  popularity  \
# 0   Jin Hee is a female urologist who runs a urolo...     150.882
# 1   Powered with incredible speed, Sonic The Hedge...     125.874
# 2   Goblin Slayer and his party head up to the sno...     101.789
# 3   Mouse desperately wants to join The Midnight C...      78.107
# 4   Harley Quinn joins forces with a singer, an as...      90.120
# 5   Tai is now a university student, living alone,...      87.424
# 6   Marcus and Mike are forced to confront new thr...      78.855
# 7   A woman falls victim to a dominant mafia boss,...      70.073
# 8   The young family who moved to a new apartment ...      58.341
# 9   In a sleepy town, one man, a wannabe horror fi...      54.687
# 10  After losing his wife seven years earlier, the...      61.049
# 11  Cha-wook and Min-joo are about to get married....      39.076
# 12  Two Swedish/Norwegian half sisters go on a win...      37.044
# 13  Responding to an urgent call for help, a polic...      43.223
# 14  Two teens facing personal struggles form a pow...      44.021
# 15  Buck is a big-hearted dog whose blissful domes...      52.411
# 16  After an airplane crash during a school trip, ...      58.747
# 17  In a suburban fantasy world, two teenage elf b...      44.276
# 18  A group of young Miskatonic University scienti...      36.728
# 19  In 2006, a group of thieves performed what is ...      37.585
#
#                          poster_path release_date  \
# 0   /uksxhYz0Xc7c5AIjoU205XXEVk8.jpg   2020-02-20
# 1   /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg   2020-02-12
# 2   /oyDaF4za9C9GxfYSyZUmj2aZGJT.jpg   2020-02-01
# 3   /8oiMFMarbRpcusASIX4cjVXoZKI.jpg   2020-01-27
# 4   /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 5   /z3l5iwWQLxcInVnNkC8k8hxqZ60.jpg   2020-02-21
# 6   /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 7   /6KwrHucIE3CvNT7kTm2MAlZ4fYF.jpg   2020-02-07
# 8   /8m5HTXzwewlfXhtZtLlLts53YTW.jpg   2020-02-27
# 9   /btrers8SNujMJhxjLvjh7AJpN3T.jpg   2020-02-18
# 10  /uoplwswBDy7gsOyrbGuKyPFoPCs.jpg   2020-01-01
# 11  /aKoGgpKn6N04kWQp03LSAweN3dn.jpg   2020-02-27
# 12  /zlOvKg5WkXcwcmqy2KaiXoXLAky.jpg   2020-02-14
# 13  /fvTGWaQejnHQBZbEOrdbb38NBTC.jpg   2020-01-30
# 14  /4SafxuMKQiw4reBiWKVZJpJn80I.jpg   2020-02-28
# 15  /33VdppGbeNxICrFUtW2WpGHvfYc.jpg   2020-02-19
# 16  /uJFki1BLHvEi4gaPCJvy9SZQZpx.jpg   2020-01-10
# 17  /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg   2020-02-29
# 18  /e6hgmD0P133bW5EH1kfhscwXN2a.jpg   2020-02-12
# 19  /1zL4VCVin4S8kOXhszMDqfwWPCM.jpg   2020-01-16
#
#                                                 title  video  vote_average  \
# 0                                 Female Urologists 2  False           7.3
# 1                                  Sonic the Hedgehog  False           7.4
# 2                       Goblin Slayer: Goblin's Crown  False           7.6
# 3                                    Charm City Kings  False           7.9
# 4   Birds of Prey (and the Fantabulous Emancipatio...  False           7.0
# 5            Digimon Adventure: Last Evolution Kizuna  False           8.1
# 6                                   Bad Boys for Life  False           7.2
# 7                                            365 Days  False           7.1
# 8                Baba Yaga: Terror of the Dark Forest  False           5.9
# 9                                     Fat Ass Zombies  False           4.9
# 10                                           Dolittle  False           6.7
# 11                                     Bosomy Tae-hee  False           8.3
# 12                                   Breaking Surface  False           6.8
# 13                                            La Casa  False           6.3
# 14                              All the Bright Places  False           7.7
# 15                               The Call of the Wild  False           7.6
# 16                        The Island of Giant Insects  False           4.4
# 17                                             Onward  False           7.8
# 18                                          Intersect  False           5.7
# 19                           The Heist of the Century  False           7.8
#
#     vote_count
# 0            5
# 1         8281
# 2          171
# 3          321
# 4         8968
# 5          174
# 6         7122
# 7         7500
# 8          186
# 9           47
# 10        3053
# 11           3
# 12         309
# 13          77
# 14        2488
# 15        2963
# 16          15
# 17        5166
# 18          48
# 19         643

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %%
import pandas as pd
import requests
import json
pd.options.display.max_columns = 30

# %%
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397,
            420818, 24428, 168259, 99861, 284054, 12445,
            181808, 330457, 351286, 109445, 321612, 260513]

# %%
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df = pd.DataFrame(json_list)

# %%
requests.get(basic_url.format(0, api_key)).status_code
# Out:
# 404

# %%
df
# Out:
#     adult                     backdrop_path  \
# 0   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1   False   /Yc9q6QuWrMp9nuDm5R8ExNqbEq.jpg
# 2   False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# 3   False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4   False  /3WjbxaqYB4vAbdUfdr5vbglD2JZ.jpg
# 5   False  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# 6   False  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 7   False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 8   False  /cHkhb5A4gQRK6zs6Pv7zorHs8Nk.jpg
# 9   False  /6YwkGolwdOMNpbTOmLjoehlVWs5.jpg
# 10  False  /6ELJEzQJ3Y45HczvreC3dg0GV5R.jpg
# 11  False  /n5A7brJCjejceZmHyujwUTVgQNC.jpg
# 12  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 13  False  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg
# 14  False  /6WA9stUMbIkEPxn3D5SWlA8FIi7.jpg
# 15  False  /fydUcbkqLyESCFa9U5XKqi8dIVj.jpg
# 16  False  /phhbtV5BEdn4TYLTMKFwYz2VSNl.jpg
# 17  False  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection     budget  \
# 0   {'id': 86311, 'name': 'The Avengers Collection...  356000000
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 3   {'id': 86311, 'name': 'The Avengers Collection...  300000000
# 4                                                None  200000000
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...  150000000
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...  260000000
# 7   {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 8   {'id': 9485, 'name': 'The Fast and the Furious...  190000000
# 9   {'id': 86311, 'name': 'The Avengers Collection...  365000000
# 10  {'id': 529892, 'name': 'Black Panther Collecti...  200000000
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...  200000000
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...  170000000
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000
# 16                                               None  160000000
# 17  {'id': 468222, 'name': 'The Incredibles Collec...  200000000
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                              homepage      id    imdb_id  \
# 0      https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1                https://www.avatar.com/movies/avatar   19995  tt0499549
# 2   http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3   https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4                                                         597  tt0120338
# 5                       http://www.jurassicworld.com/  135397  tt0369610
# 6        https://movies.disney.com/the-lion-king-2019  420818  tt6105098
# 7          https://www.marvel.com/movies/the-avengers   24428  tt0848228
# 8           https://www.thefastsaga.com/fast-saga/ff7  168259  tt2820852
# 9   http://marvel.com/movies/movie/193/avengers_ag...   99861  tt2395427
# 10        https://www.marvel.com/movies/black-panther  284054  tt1825683
# 11  https://www.warnerbros.com/movies/harry-potter...   12445  tt1201607
# 12  https://www.starwars.com/films/star-wars-episo...  181808  tt2527336
# 13                 https://movies.disney.com/frozen-2  330457  tt4520988
# 14                       http://www.jurassicworld.com  351286  tt4881806
# 15                    http://movies.disney.com/frozen  109445  tt2294629
# 16  http://movies.disney.com/beauty-and-the-beast-...  321612  tt2771200
# 17            https://movies.disney.com/incredibles-2  260513  tt3606756
#
#    original_language                                original_title  \
# 0                 en                             Avengers: Endgame
# 1                 en                                        Avatar
# 2                 en                  Star Wars: The Force Awakens
# 3                 en                        Avengers: Infinity War
# 4                 en                                       Titanic
# 5                 en                                Jurassic World
# 6                 en                                 The Lion King
# 7                 en                                  The Avengers
# 8                 en                                     Furious 7
# 9                 en                       Avengers: Age of Ultron
# 10                en                                 Black Panther
# 11                en  Harry Potter and the Deathly Hallows: Part 2
# 12                en                      Star Wars: The Last Jedi
# 13                en                                     Frozen II
# 14                en                Jurassic World: Fallen Kingdom
# 15                en                                        Frozen
# 16                en                          Beauty and the Beast
# 17                en                                 Incredibles 2
#
#                                              overview  popularity  \
# 0   After the devastating events of Avengers: Infi...     183.509
# 1   In the 22nd century, a paraplegic Marine is di...     641.325
# 2   Thirty years after defeating the Galactic Empi...      63.835
# 3   As the Avengers and their allies have continue...     310.526
# 4   101-year-old Rose DeWitt Bukater tells the sto...     141.597
# 5   Twenty-two years after the events of Jurassic ...     111.838
# 6   Simba idolizes his father, King Mufasa, and ta...     161.207
# 7   When an unexpected enemy emerges and threatens...     201.794
# 8   Deckard Shaw seeks revenge against Dominic Tor...     103.200
# 9   When Tony Stark tries to jumpstart a dormant p...     169.308
# 10  King T'Challa returns home to the reclusive, t...     102.310
# 11  Harry, Ron and Hermione continue their quest t...     160.495
# 12  Rey develops her newly discovered abilities wi...      58.877
# 13  Elsa, Anna, Kristoff and Olaf head far into th...     146.194
# 14  Three years after the demise of Jurassic World...      93.335
# 15  Young princess Anna of Arendelle dreams about ...     143.723
# 16  A live-action adaptation of Disney's version o...      96.675
# 17  Elastigirl springs into action to save the day...     106.630
#
#                          poster_path  \
# 0   /or06FN3Dka5tukK1e9sl16pB3iy.jpg
# 1   /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 2   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 3   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
# 4   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 5   /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg
# 6   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg
# 7    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# 8   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg
# 9   /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
# 10  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg
# 11  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 12  /ySaaKHOLAQU5HoZqWmzDIj1VvZ1.jpg
# 13  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg
# 14  /c9XxwwhPHdaImA2f1WEfEsbhaFB.jpg
# 15  /kgwjIb2JDHRhNk13lmSxiClFjVk.jpg
# 16  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg
# 17  /aTbRJHCrQwceSS5b8LYj7hC654I.jpg
#
#                                  production_companies  \
# 0   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 1   [{'id': 25, 'logo_path': '/qZCc1lty5FzX30aOCVR...
# 2   [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# 3   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# 5   [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 6   [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 7   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 8   [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 9   [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 10  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 11  [{'id': 174, 'logo_path': '/IuAlhI9eVC9Z8UQWOI...
# 12  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# 13  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 14  [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 15  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 16  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 17  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
#
#                                  production_countries release_date  \
# 0   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24
# 1   [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-10
# 2   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15
# 3   [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25
# 4   [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18
# 5   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-06
# 6   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-07-12
# 7   [{'iso_3166_1': 'US', 'name': 'United States o...   2012-04-25
# 8   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-01
# 9   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-22
# 10  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-02-13
# 11  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2011-07-07
# 12  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-13
# 13  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-11-20
# 14  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-06
# 15  [{'iso_3166_1': 'US', 'name': 'United States o...   2013-11-20
# 16  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-03-16
# 17  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-14
#
#        revenue  runtime                                   spoken_languages  \
# 0   2797800564      181  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1   2847246203      162  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2   2068223624      136  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   2046239637      149  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4   2187463944      194  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5   1671713208      124  [{'english_name': 'English', 'iso_639_1': 'en'...
# 6   1667635327      118  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7   1518815515      143  [{'english_name': 'English', 'iso_639_1': 'en'...
# 8   1515047671      137  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# 9   1405403694      141  [{'english_name': 'English', 'iso_639_1': 'en'...
# 10  1347597973      135  [{'english_name': 'English', 'iso_639_1': 'en'...
# 11  1341511219      130  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12  1332698830      152  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13  1450026933      103  [{'english_name': 'English', 'iso_639_1': 'en'...
# 14  1310466296      129  [{'english_name': 'English', 'iso_639_1': 'en'...
# 15  1274219009      102  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16  1263521126      129  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17  1242805359      118  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#       status                                            tagline  \
# 0   Released                                 Avenge the fallen.
# 1   Released                        Enter the world of Pandora.
# 2   Released                      Every generation has a story.
# 3   Released              An entire universe. Once and for all.
# 4   Released          Nothing on Earth could come between them.
# 5   Released                                  The park is open.
# 6   Released                             The King has Returned.
# 7   Released                            Some assembly required.
# 8   Released                                Vengeance hits home
# 9   Released                                A New Age Has Come.
# 10  Released                                Long live the king.
# 11  Released                                  It all ends here.
# 12  Released             Darkness rises... and light to meet it
# 13  Released                     The past is not what it seems.
# 14  Released                                  The park is gone.
# 15  Released  Only the act of true love will thaw a frozen h...
# 16  Released                                      Be our guest.
# 17  Released                                      Back to work.
#
#                                            title  video  vote_average  \
# 0                              Avengers: Endgame  False         8.278
# 1                                         Avatar  False         7.517
# 2                   Star Wars: The Force Awakens  False         7.315
# 3                         Avengers: Infinity War  False         8.266
# 4                                        Titanic  False         7.876
# 5                                 Jurassic World  False         6.675
# 6                                  The Lion King  False         7.140
# 7                                   The Avengers  False         7.706
# 8                                      Furious 7  False         7.239
# 9                        Avengers: Age of Ultron  False         7.290
# 10                                 Black Panther  False         7.396
# 11  Harry Potter and the Deathly Hallows: Part 2  False         8.119
# 12                      Star Wars: The Last Jedi  False         6.857
# 13                                     Frozen II  False         7.299
# 14                Jurassic World: Fallen Kingdom  False         6.561
# 15                                        Frozen  False         7.255
# 16                          Beauty and the Beast  False         6.969
# 17                                 Incredibles 2  False         7.500
#
#     vote_count
# 0        21750
# 1        26015
# 2        17325
# 3        25381
# 4        21508
# 5        18436
# 6         8640
# 7        27488
# 8         9287
# 9        20324
# 10       19494
# 11       17693
# 12       13327
# 13        8401
# 14       10210
# 15       14532
# 16       14277
# 17       11209

# %%
df = df.loc[:, ["title", "id", "revenue", "genres", "belongs_to_collection", "runtime"]].sort_values(by = "revenue",
                                                                                                ascending = False)

# %%
df
# Out:
#                                            title      id     revenue  \
# 1                                         Avatar   19995  2847246203
# 0                              Avengers: Endgame  299534  2797800564
# 4                                        Titanic     597  2187463944
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1667635327
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515047671
# 13                                     Frozen II  330457  1450026933
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1347597973
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  \
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 4                                                None      194
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      103
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      135
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.to_json("movies.json", orient = "records")

# %%
with open("movies.json") as f:
    data = json.load(f)

# %%
pd.json_normalize(data)
# Out:
#                                            title      id     revenue  \
# 0                                         Avatar   19995  2847246203
# 1                              Avengers: Endgame  299534  2797800564
# 2                                        Titanic     597  2187463944
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1667635327
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515047671
# 9                                      Frozen II  330457  1450026933
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1347597973
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 13                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  runtime  \
# 0   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 2   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      136
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      103
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      135
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      152
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection.id           belongs_to_collection.name  \
# 0                    87096.0                    Avatar Collection
# 1                    86311.0              The Avengers Collection
# 2                        NaN                                  NaN
# 3                       10.0                 Star Wars Collection
# 4                    86311.0              The Avengers Collection
# 5                      328.0             Jurassic Park Collection
# 6                   762512.0    The Lion King (Reboot) Collection
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                   386382.0                    Frozen Collection
# 10                   86311.0              The Avengers Collection
# 11                  529892.0             Black Panther Collection
# 12                    1241.0              Harry Potter Collection
# 13                      10.0                 Star Wars Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 0   /gC3tW9a45RGOzzSh6wv91pFnmFr.jpg    /6qkJLRCZp9Y3ovXti5tSuhH0DpO.jpg
# 1   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 2                                NaN                                 NaN
# 3   /gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 4   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 5   /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 6   /dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg    /jIgM7YNVft0YGeXsqrh3oG5TWLx.jpg
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /yvr1Ziehgps1VJyug8nnezTJRJW.jpg    /gC9BUFiROWtaMsluGYziZ6lR4OJ.jpg
# 9   /2DdKGQYzE6D7pSvvHvM9FRzTh5r.jpg    /6QonAoIN0jhWZZWZGJswSxHzUnU.jpg
# 10  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 11  /uVnN6KnfDuHiC8rsVsSc7kk0WRD.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 12  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /4gV0rKUjB1nLUdZB4zIltLvNZZr.jpg
# 13  /gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 14  /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 15  /2DdKGQYzE6D7pSvvHvM9FRzTh5r.jpg    /6QonAoIN0jhWZZWZGJswSxHzUnU.jpg
# 16                               NaN                                 NaN
# 17  /xMX1jZyObVeWUxDQmt53X6jzIO4.jpg    /6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %%
pd.json_normalize(data, "genres", "title")
# Out:
#        id             name                 title
# 0      28           Action                Avatar
# 1      12        Adventure                Avatar
# 2      14          Fantasy                Avatar
# 3     878  Science Fiction                Avatar
# 4      12        Adventure     Avengers: Endgame
# ..    ...              ...                   ...
# 57  10749          Romance  Beauty and the Beast
# 58     28           Action         Incredibles 2
# 59     12        Adventure         Incredibles 2
# 60     16        Animation         Incredibles 2
# 61  10751           Family         Incredibles 2
#
# [62 rows x 3 columns]

# %% [markdown]
# # Importing and Saving the Movies Dataset (Real World Scenario)

# %%
df
# Out:
#                                            title      id     revenue  \
# 1                                         Avatar   19995  2847246203
# 0                              Avengers: Endgame  299534  2797800564
# 4                                        Titanic     597  2187463944
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1667635327
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515047671
# 13                                     Frozen II  330457  1450026933
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1347597973
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  \
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 13  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 4                                                None      194
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6   {'id': 762512, 'name': 'The Lion King (Reboot)...      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      103
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      135
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.to_csv("movies_raw.csv", index = False)

# %%
df = pd.read_csv("movies_raw.csv")

# %%
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                 NaN      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                 NaN      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                                NaN      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.genres[0]
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]"
